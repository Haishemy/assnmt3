# %%
import pandas as pd
import numpy as np

# %%
dataset= pd.read_csv('Student_Performance.csv')
dataset
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Performance Index  \
# 0                                    1                 91
# 1                                    2                 65
# 2                                    2                 45
# 3                                    2                 36
# 4                                    5                 66
# ...

# %%
dataset.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Sleep Hours',
#        'Sample Question Papers Practiced', 'Performance Index',
#        'Extracurricular Activities_Yes'],
#       dtype='object')

# %%
indep= dataset[['Hours Studied', 'Previous Scores', 'Sleep Hours',
       'Sample Question Papers Practiced','Extracurricular Activities_Yes']]
dep= dataset[['Performance Index']]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid= {'criterion':['squared_error' ,'friedman_mse', 'absolute_error', 'poisson'],
             'splitter':['best', 'random'],
             'max_features':['sqrt','log2']}
grid= GridSearchCV (DecisionTreeRegressor(), param_grid, refit=True, verbose=0, n_jobs=1)
grid.fit(indep, dep)
# Out:
# C:\Users\haish\anaconda3\envs\aiml\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\haish\anaconda3\envs\aiml\lib\site-packages\sklearn\model_selection\_validation.py:530: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10032\3020553969.py in <module>
#       5              'max_features':['sqrt','log2']}
#       6 grid= GridSearchCV (DecisionTreeRegressor(), param_grid, refit=True, verbose=0, n_jobs=1)
# ...

# %%
import pickle
filename="finalized_model_svr.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open(filename,'rb'))
result= loaded_model.predict([[5,52,5,2,1]])
result
